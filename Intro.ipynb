# %% [markdown]
# Inroduction and Problem
#
# Health insurance can be unpredictable and expensive. It can be scary when you are first start looking into getting insured. This model looks to remedy this by giving a prediction to see what you will be paying based on multiple aspects of your life. These models will also look at the most costly factors companies will charge you for so you can determine what you should do in order decrease the cost of your health insurance.
#
# Data
#
# This model will look at prices charged by various companies in the US to give an average estimate. Charges will vary depending on the specific isnurance provider and plan that you choose. The features that will be anylized are age, BMI, if you are a smoker, The region of the US that you live in, sex, number of children, age/smoking status coorelation, and
